# %%
import pandas as pd

# %%
df = pd.read_excel("test 2 text.xlsx")

# %%
data=df[:9000]

# %%
data
# Out:
#                                                    text
# 0     ممتاز 9/99   نوعا ما . النظافة والموقع والتجهي...
# 1     أحد أسباب نجاح الإمارات أن كل شخص في 8965 الدو...
# 2     هادفة .. وقوية. تنقلك من صخب شوارع القاهرة الى...
# 3     خلصنا .. مبدئيا اللي مستني ابهار زي الفيل الاز...
# 4     أسلوب الكاتب رائع جدا و عميق جدا، قرأته عدة مر...
# ...                                                 ...
# 8995  اعتقد ان تامر ابراهيم بيبدع اكتر لما يكتب حاجة...
# 8996  سمعت الكتاب فى حديث مينا فى تيدكس كايرو اسلوبه...
# 8997  رائعة... أكثر ما أعجبني السرد الممتع و رصد تأث...
# 8998                              ممتاز. الطاقم. الموقع
# 8999  جيد جدا. موقع جميل قريب من المطاعم الموظف مارك...
#
# [9000 rows x 1 columns]

# %%
df.head()
# Out:
#                                                 text
# 0  ممتاز 9/99   نوعا ما . النظافة والموقع والتجهي...
# 1  أحد أسباب نجاح الإمارات أن كل شخص في 8965 الدو...
# 2  هادفة .. وقوية. تنقلك من صخب شوارع القاهرة الى...
# 3  خلصنا .. مبدئيا اللي مستني ابهار زي الفيل الاز...
# 4  أسلوب الكاتب رائع جدا و عميق جدا، قرأته عدة مر...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\QUSAI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords.words('arabic')
# Out:
# ['إذ',
#  'إذا',
#  'إذما',
#  'إذن',
#  'أف',
#  'أقل',
#  'أكثر',
#  'ألا',
#  'إلا',
#  'التي',
#  'الذي',
#  'الذين',
#  'اللاتي',
#  'اللائي',
#  'اللتان',
#  'اللتيا',
#  'اللتين',
#  'اللذان',
#  'اللذين',
#  'اللواتي',
#  'إلى',
#  'إليك',
#  'إليكم',
#  'إليكما',
#  'إليكن',
#  'أم',
#  'أما',
#  'أما',
#  'إما',
#  'أن',
#  'إن',
#  'إنا',
#  'أنا',
#  'أنت',
#  'أنتم',
#  'أنتما',
#  'أنتن',
#  'إنما',
#  'إنه',
#  'أنى',
#  'أنى',
#  'آه',
#  'آها',
#  'أو',
#  'أولاء',
#  'أولئك',
#  'أوه',
#  'آي',
#  'أي',
#  'أيها',
#  'إي',
#  'أين',
#  'أين',
#  'أينما',
#  'إيه',
#  'بخ',
#  'بس',
#  'بعد',
#  'بعض',
#  'بك',
#  'بكم',
#  'بكم',
#  'بكما',
#  'بكن',
#  'بل',
#  'بلى',
#  'بما',
#  'بماذا',
#  'بمن',
#  'بنا',
#  'به',
#  'بها',
#  'بهم',
#  'بهما',
#  'بهن',
#  'بي',
#  'بين',
#  'بيد',
#  'تلك',
#  'تلكم',
#  'تلكما',
#  'ته',
#  'تي',
#  'تين',
#  'تينك',
#  'ثم',
#  'ثمة',
#  'حاشا',
#  'حبذا',
#  'حتى',
#  'حيث',
#  'حيثما',
#  'حين',
#  'خلا',
#  'دون',
# ...

# %%
s=df['text'][0]
s
# Out:
# 'ممتاز 9/99   نوعا ما . النظافة والموقع والتجهيز والشاطيء. المطعم'

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
import re
s=re.sub('[0-9! "#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]'," ",s)

# %%
s
# Out:
# 'ممتاز        نوعا ما   النظافة والموقع والتجهيز والشاطيء  المطعم'

# %%
s=s.split()
s
# Out:
# ['ممتاز', 'نوعا', 'ما', 'النظافة', 'والموقع', 'والتجهيز', 'والشاطيء', 'المطعم']

# %%
t=[]
for word in s:
    if word not in stopwords.words('arabic'):
        t.append(word)
t
# Out:
# ['ممتاز', 'نوعا', 'النظافة', 'والموقع', 'والتجهيز', 'والشاطيء', 'المطعم']

# %%
s= " ".join(t)
s
# Out:
# 'ممتاز نوعا النظافة والموقع والتجهيز والشاطيء المطعم'

# %%
#df["text"]=df["text"].astype('category')

# %%
n_text=[]

for i in range(len(data)):
    s=re.sub('[0-9! "#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]'," ",str(data["text"][i]))
    s=s.split()
    s=[word for word in s if word not in stopwords.words("arabic")]
    s= " ".join(s)
    n_text.append(s)

# %%
data["n_text"]=n_text
# Out:
# <ipython-input-138-72269fb7d8f0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["n_text"]=n_text

# %%
data.head()
# Out:
#                                                 text  \
# 0  ممتاز 9/99   نوعا ما . النظافة والموقع والتجهي...
# 1  أحد أسباب نجاح الإمارات أن كل شخص في 8965 الدو...
# 2  هادفة .. وقوية. تنقلك من صخب شوارع القاهرة الى...
# 3  خلصنا .. مبدئيا اللي مستني ابهار زي الفيل الاز...
# 4  أسلوب الكاتب رائع جدا و عميق جدا، قرأته عدة مر...
#
#                                               n_text
# 0  ممتاز نوعا النظافة والموقع والتجهيز والشاطيء ا...
# 1  أسباب نجاح الإمارات شخص الدولة يعشق ترابها نحب...
# 2  هادفة وقوية تنقلك صخب شوارع القاهرة الى هدوء ج...
# 3  خلصنا مبدئيا اللي مستني ابهار زي الفيل الازرق ...
# 4  أسلوب الكاتب رائع جدا عميق جدا، قرأته عدة مرات...

# %%
z=data["text"]==data["n_text"].sum()

# %%
z.value_counts()
# Out:
# False    9000
# Name: text, dtype: int64
